# %%
import pandas as pd
import numpy as np

# %%
data = [[1,2,3] , [2,3,4] , [4,5,6]]

df = pd.DataFrame(data , columns=["A" , "B" , "C"])

df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  2  3  4
# 2  4  5  6

# %%
coffee = pd.read_csv("./data/coffee.csv")
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# ACCESSING DATA WITH PANDAS

# %%
coffee
# coffee.sample(10) 
# to access the different data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[5:10 , ["Day" , "Units Sold"]]
# coffee.iloc[: , [0,2]]

coffee.iloc[1:5 , [0]]
# Out:
#          Day
# 1     Monday
# 2    Tuesday
# 3    Tuesday
# 4  Wednesday

# %%
# coffee.index = coffee.Day
# coffee.index = coffee["Day"]
# print(coffee.index)

# coffee.loc[1 , "Units Sold"] = 10
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# coffee.sort_values(by = "Units Sold" , ascending=True)
# coffee.sort_values(by = "Units Sold" , ascending=False)
# coffee.sort_values(by = ["Units Sold" , "Coffee Type"] , ascending=[0,1])
coffee.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %% [markdown]
# FILTRING DATA

# %%
import pandas as pd 
bios = pd.read_csv("./data/bios.csv")
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios["height_cm"]>215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
# bios.loc[(bios["height_cm"] > 215) & (bios["born_country"] == "USA")]
# bios.loc[(bios["height_cm"] > 215) & (bios["born_country"] == "USA") , "name"]
# bios.loc[(bios["height_cm"] > 215) & (bios["born_country"] == "USA") , ["name" , "height_cm" ]]

# bios[bios["height_cm"] > 215 ] ["name"]
# bios[(bios["height_cm"] > 215) & (bios["born_country"] == "USA")] ["name"]
# Out:
# 5089         Viktor Pankrashkin
# 5583       Paulinho Villas Boas
# 5673             Gunther Behnke
# 5716                   Uwe Blab
# 5781             Tommy Burleson
# 5796              Andy Campbell
# 6223                Lars Hansen
# 6270                Hu Zhangbao
# 6409           Sergey Kovalenko
# 6420              Jānis Krūmiņš
# 6504                Luc Longley
# 6722           Shaquille O'Neal
# 6937             David Robinson
# 6978            Arvydas Sabonis
# 7074             Paulo da Silva
# 7188         Vladimir Tkachenko
# 7281           Stojko Vranković
# 7376        Eurelijus Žukauskas
# 52608           Aleksey Kazakov
# 82100             Frédéric Weis
# 89070                  Yao Ming
# 89075            Roberto Dueñas
# 107408         Peter John Ramos
# 112312             Stanko Barać
# 112332      Andreas Glyniadakis
# 112337            Hamed Haddadi
# 118663           Timofey Mozgov
# 118676          Dmitry Musersky
# 120266             Zhang Zhaoxu
# ...

# %% [markdown]
# QUERY FILTRING

# %%
bios[bios["name"].str.contains("Peter" , case=False) ]
# Out:
#         athlete_id             name   born_date   born_city      born_region  \
# 102            103    Peter Knowles  1969-12-28   Stockport          England
# 140            141      Peter Franz  1971-04-25   Stolzenau    Niedersachsen
# 308            309   Peter Mitterer  1947-04-12     Gmunden   Oberösterreich
# 574            576     Peter Gillam  1956-01-02  Folkestone          England
# 621            624  Peter Blackburn  1968-03-25    Ballarat         Victoria
# ...            ...              ...         ...         ...              ...
# 144564      148256      Peter Regin  1986-04-16     Herning      Midtjylland
# 145239      148958    Dominik Peter  2001-05-30      Zürich           Zürich
# 145247      148966   Peter Cehlárik  1995-08-02      Žilina           Žilina
# 145262      148982      Peter Zuzin  1990-09-04      Zvolen  Banská Bystrica
# 145366      149089    Tara Peterson  1991-05-28  Burnsville        Minnesota
#
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ADDING DELETING COLUMNS

# %%
coffee = pd.read_csv("./data/coffee.csv")

coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee["price"] = 3.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   3.99
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   3.99
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   3.99
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   3.99
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   3.99
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   3.99
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   3.99

# %%
coffee["Total Revene"] = coffee["Units Sold"] * coffee["price"]

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  Total Revene
# 0      Monday    Espresso          25   3.99         99.75
# 1      Monday       Latte          15   3.99         59.85
# 2     Tuesday    Espresso          30   3.99        119.70
# 3     Tuesday       Latte          20   3.99         79.80
# 4   Wednesday    Espresso          35   3.99        139.65
# 5   Wednesday       Latte          25   3.99         99.75
# 6    Thursday    Espresso          40   3.99        159.60
# 7    Thursday       Latte          30   3.99        119.70
# 8      Friday    Espresso          45   3.99        179.55
# 9      Friday       Latte          35   3.99        139.65
# 10   Saturday    Espresso          45   3.99        179.55
# 11   Saturday       Latte          35   3.99        139.65
# 12     Sunday    Espresso          45   3.99        179.55
# 13     Sunday       Latte          35   3.99        139.65

# %%
# coffee = coffee.assign(Profit=lambda x: x["Units Sold"] * 2)
# coffee.head()
# Save before removing
# Reorder the columns as you want
# coffee = coffee[["Day", "Coffee Type", "Units Sold", "Profit"]]


# coffee["Units Sold"] = coffee["Profit"] // 2
# print(coffee.columns.tolist())


# coffee.drop(columns="Units Sold" , inplace = True)
coffee
# Out:
#           Day Coffee Type  Units Sold  Profit
# 0      Monday    Espresso          25      50
# 1      Monday       Latte          15      30
# 2     Tuesday    Espresso          30      60
# 3     Tuesday       Latte          20      40
# 4   Wednesday    Espresso          35      70
# 5   Wednesday       Latte          25      50
# 6    Thursday    Espresso          40      80
# 7    Thursday       Latte          30      60
# 8      Friday    Espresso          45      90
# 9      Friday       Latte          35      70
# 10   Saturday    Espresso          45      90
# 11   Saturday       Latte          35      70
# 12     Sunday    Espresso          45      90
# 13     Sunday       Latte          35      70

# %%
# coffee.drop(columns=["Profit"] , inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee1 = coffee[coffee["Units Sold"] >= 30]
coffee1
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# MERGING AND CONCATINFG DATA

# %%
import pandas as pd

# %%
nocs = pd.read_csv("./data/noc_regions.csv")
bios = pd.read_csv("./data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
merged = pd.merge(bios, nocs, left_on="born_country" , right_on="NOC" , how="left")
merged.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y  region notes
# 0  1960-10-02   FRA  France   NaN
# 1         NaN   FRA  France   NaN
# 2  1994-07-17   FRA  France   NaN
# 3  1978-03-20   FRA  France   NaN
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN
